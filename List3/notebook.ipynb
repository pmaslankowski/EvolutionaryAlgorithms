# %%
# %load_ext autoreload
# %autoreload 2

# %%
from IPython.display import HTML
HTML('''<script>
code_show_err=false; 
function code_toggle_err() {
 if (code_show_err){
 $('div.output_stderr').hide();
 } else {
 $('div.output_stderr').show();
 }
 code_show_err = !code_show_err
} 
$( document ).ready(code_toggle_err);
</script>
To toggle on/off output_stderr, click <a href="javascript:code_toggle_err()">here</a>.''')
# Out:
# <script>
# code_show_err=false;
# function code_toggle_err() {
#  if (code_show_err){
#  $('div.output_stderr').hide();
#  } else {
#  $('div.output_stderr').show();
#  }
#  code_show_err = !code_show_err
# }
# $( document ).ready(code_toggle_err);
# </script>
# To toggle on/off output_stderr, click <a href="javascript:code_toggle_err()">here</a>.

# %%
import numpy as np
from utils import run_test, plot_objective, plot_history, plot_sigmas, show_results

# %% [markdown]
# ## Griewank's function

# %% [markdown]
# ### Function plots:

# %%
plot_objective('griewank')

# %%
plot_objective('griewank', range_min=-50, range_max=50)

# %% [markdown]
# ### Optimization

# %%
params = {'function_name': 'griewank',
          'mu': 10000,
          'lam': 20000,
          'd': 10,
          'K': 1,
          'max_iters': 1000,
          'mode': 'plus'}

griewank10 = run_test(**params)
# Out:
# t = 0, max = -50.27489787230955, avg_sigma = 0.01, iter time = 0.04s ETA = 36.38s
# t = 200, max = -1.7039206881715856, avg_sigma = 0.12, iter time = 0.03s ETA = 25.07s
# t = 400, max = -1.7038785532731238, avg_sigma = 0.00, iter time = 0.03s ETA = 17.84s
# t = 600, max = -1.7038785532731238, avg_sigma = 0.00, iter time = 0.03s ETA = 11.83s
# t = 800, max = -1.7038785532731238, avg_sigma = 0.00, iter time = 0.03s ETA = 5.90s

# %%
params = {'function_name': 'griewank',
          'mu': 100000,
          'lam': 200000,
          'd': 30,
          'K': 1,
          'max_iters': 1000,
          'mode': 'plus'}

griewank30 = run_test(**params)
# Out:
# t = 0, max = -337.5357580638697, avg_sigma = -0.00, iter time = 1.05s ETA = 1054.20s
# t = 200, max = -29.40332276326413, avg_sigma = -0.01, iter time = 1.13s ETA = 903.42s
# t = 400, max = -25.068449840416992, avg_sigma = -0.01, iter time = 1.10s ETA = 662.31s
# t = 600, max = -20.30634848703384, avg_sigma = -0.01, iter time = 1.11s ETA = 443.60s
# t = 800, max = -20.30335352881397, avg_sigma = -0.00, iter time = 1.11s ETA = 222.18s

# %%
params = {'function_name': 'griewank',
          'mu': 100000,
          'lam': 200000,
          'd': 50,
          'K': 1,
          'max_iters': 1000,
          'mode': 'plus'}

griewank50 = run_test(**params)
# Out:
# t = 0, max = -750.9229441355155, avg_sigma = -0.00, iter time = 1.70s ETA = 1699.68s
# t = 200, max = -193.4694122558283, avg_sigma = 0.00, iter time = 1.69s ETA = 1351.60s
# t = 400, max = -126.70083248069042, avg_sigma = -0.00, iter time = 1.69s ETA = 1012.15s
# t = 600, max = -118.58638491587716, avg_sigma = -0.01, iter time = 1.69s ETA = 674.55s
# t = 800, max = -111.23105833434762, avg_sigma = -0.01, iter time = 1.70s ETA = 340.52s

# %%
params = {'function_name': 'griewank',
          'mu': 100000,
          'lam': 200000,
          'd': 80,
          'K': 1,
          'max_iters': 1000,
          'mode': 'plus'}

griewank50 = run_test(**params)
# Out:
# t = 0, max = -1403.5589985781137, avg_sigma = 0.00, iter time = 2.64s ETA = 2636.48s
# t = 200, max = -667.774722055055, avg_sigma = 0.01, iter time = 2.66s ETA = 2125.23s
# t = 400, max = -414.6073297286922, avg_sigma = 0.00, iter time = 2.68s ETA = 1609.35s
# t = 600, max = -349.4107524472928, avg_sigma = -0.00, iter time = 2.67s ETA = 1068.31s
# t = 800, max = -321.4642147707652, avg_sigma = 0.00, iter time = 2.64s ETA = 527.85s

# %%
params = {'function_name': 'griewank',
          'mu': 100000,
          'lam': 200000,
          'd': 150,
          'K': 1,
          'max_iters': 1000,
          'mode': 'plus'}

griewank50 = run_test(**params)
# Out:
# t = 0, max = -3216.0880250800838, avg_sigma = 0.00, iter time = 4.81s ETA = 4814.36s
# t = 200, max = -2303.022012556644, avg_sigma = -0.17, iter time = 4.87s ETA = 3897.11s
# t = 400, max = -1436.5744490596824, avg_sigma = 0.01, iter time = 4.88s ETA = 2925.26s
# t = 600, max = -980.520194583067, avg_sigma = 0.01, iter time = 4.89s ETA = 1957.82s
# t = 800, max = -793.8507995071495, avg_sigma = 0.00, iter time = 4.91s ETA = 981.39s

# %% [markdown]
# ### Rastrigin's function

# %%
plot_objective('rastrigin')

# %%
show_results('rastrigin', 10, 'plus')
# Out:
# Max value found: [-2.98487717]

# %%
show_results('rastrigin', 30, 'plus')
# Out:
# Max value found: [-75.96467013]

# %%
show_results('rastrigin', 50, 'plus')
# Out:
# Max value found: [-289.6971594]

# %%
show_results('rastrigin', 80, 'plus')
# Out:
# Max value found: [-526.18336323]

# %%
show_results('rastrigin', 150, 'plus')
# Out:
# Max value found: [-1441.16639321]

# %% [markdown]
# ### Schwefel's function

# %%
plot_objective('schwefel')

# %%
show_results('schwefel', 10, 'plus')
# Out:
# Max value found: [-151.4429258]

# %%
show_results('schwefel', 30, 'plus')
# Out:
# Max value found: [-2025.59141575]

# %%
show_results('schwefel', 50, 'plus')
# Out:
# Max value found: [-4678.9057059]

# %%
show_results('schwefel', 80, 'plus')
# Out:
# Max value found: [-10403.95511277]

# %%
show_results('schwefel', 150, 'plus')
# Out:
# Max value found: [-26018.31915661]

# %% [markdown]
# ### Ackleys's function

# %%
plot_objective('ackley')

# %%
show_results('ackley', 10, 'plus')
# Out:
# Max value found: [-4.4408921e-16]

# %%
show_results('ackley', 30, 'plus')
# Out:
# Max value found: [-0.38746581]

# %%
show_results('ackley', 50, 'plus')
# Out:
# Max value found: [-1.34697231]

# %%
show_results('ackley', 80, 'plus')
# Out:
# Max value found: [-4.86548465]

# %%
show_results('ackley', 150, 'plus')
# Out:
# Max value found: [-7.98192795]

# %% [markdown]
# ### Rosenbrock's function

# %%
plot_objective('rosenbrock')

# %%
show_results('rosenbrock', 10, 'plus')
# Out:
# Max value found: [-0.08373064]

# %%
show_results('rosenbrock', 30, 'plus')
# Out:
# Max value found: [-62.25191955]

# %%
show_results('rosenbrock', 50, 'plus')
# Out:
# Max value found: [-1732.87361913]

# %%
show_results('rosenbrock', 80, 'plus')
# Out:
# Max value found: [-33806.09895112]

# %%
show_results('rosenbrock', 150, 'plus')
# Out:
# Max value found: [-161998.58363389]

# %% [markdown]
# ### ESComma

# %% [markdown]
# #### Griewank

# %%
plot_objective('rastrigin')

# %%
show_results('rastrigin', 10, 'comma')
# Out:
# Max value found: [-59.76543597]

# %%
show_results('rastrigin', 30, 'comma')
# Out:
# Max value found: [-407.25608128]

# %%
show_results('rastrigin', 50, 'comma')
# Out:
# Max value found: [-686.77877552]

# %%
show_results('rastrigin', 80, 'comma')
# Out:
# Max value found: [-1213.51678242]

# %%
show_results('rastrigin', 150, 'comma')
# Out:
# Max value found: [-2823.18910106]

# %% [markdown]
# #### Schwefel

# %%
plot_objective('schwefel')

# %%
show_results('schwefel', 10, 'comma')
# Out:
# Max value found: [-1193.33277307]

# %%
show_results('schwefel', 30, 'comma')
# Out:
# Max value found: [-5822.89214853]

# %%
show_results('schwefel', 50, 'comma')
# Out:
# Max value found: [-10738.25038743]

# %%
show_results('schwefel', 80, 'comma')
# Out:
# Max value found: [-18104.3958357]

# %%
show_results('schwefel', 150, 'comma')
# Out:
# Max value found: [-35003.14197338]

# %% [markdown]
# #### Ackley

# %%
show_results('ackley', 10, 'comma')
# Out:
# Max value found: [-8.76129354]

# %%
show_results('ackley', 30, 'comma')
# Out:
# Max value found: [-15.01586622]

# %%
show_results('ackley', 50, 'comma')
# Out:
# Max value found: [-17.5687889]

# %%
show_results('ackley', 80, 'comma')
# Out:
# Max value found: [-16.84826318]

# %%
show_results('ackley', 150, 'comma')
# Out:
# Max value found: [-19.8116635]

# %% [markdown]
# ### Rosenbrock

# %%
show_results('rosenbrock', 10, 'comma')
# Out:
# Max value found: [-8.41392799]

# %%
show_results('rosenbrock', 30, 'comma')
# Out:
# Max value found: [-76901.86908427]

# %%
show_results('rosenbrock', 50, 'comma')
# Out:
# Max value found: [-237142.36857442]

# %%
show_results('rosenbrock', 80, 'comma')
# Out:
# Max value found: [-626307.08725692]

# %%
show_results('rosenbrock', 150, 'comma')
# Out:
# Max value found: [-4305880.33670628]
